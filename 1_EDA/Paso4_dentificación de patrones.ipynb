# %% [markdown]
# # Análisis de Redes Complejas para la Identificación de Patrones de Comportamiento en las Ventas

# %%
pip install "notebook>=5.3" "ipywidgets>=7.5"
# Out:
# Requirement already satisfied: notebook>=5.3 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (7.2.2)
# Requirement already satisfied: ipywidgets>=7.5 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from notebook>=5.3) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from notebook>=5.3) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from notebook>=5.3) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from notebook>=5.3) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/insightlab/.local/lib/python3.10/site-packages (from notebook>=5.3) (6.4.1)
# Requirement already satisfied: comm>=0.1.3 in /home/insightlab/.local/lib/python3.10/site-packages (from ipywidgets>=7.5) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/insightlab/.local/lib/python3.10/site-packages (from ipywidgets>=7.5) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/insightlab/.local/lib/python3.10/site-packages (from ipywidgets>=7.5) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from ipywidgets>=7.5) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from ipywidgets>=7.5) (3.0.13)
# Requirement already satisfied: decorator in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (2.18.0)
# Requirement already satisfied: stack-data in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (1.2.1)
# Requirement already satisfied: typing-extensions>=4.6 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (4.9.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (26.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.3) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.3) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.3) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.3) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.3) (72.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.3) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.3) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.3) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.3) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.3) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.10)
# Requirement already satisfied: sniffio>=1.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.3) (21.2.0)
# Requirement already satisfied: certifi in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.3) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.3) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.3) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.3) (1.8.2)
# Requirement already satisfied: nest-asyncio in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.3) (1.6.0)
# Requirement already satisfied: psutil in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.3) (6.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/insightlab/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/insightlab/.local/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.3) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.3) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.3) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.3) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=5.3) (4.2.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (6.1.0)
# Requirement already satisfied: defusedxml in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/insightlab/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/insightlab/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=5.3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=5.3) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/insightlab/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/insightlab/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (2.4.1)
# Requirement already satisfied: pure-eval in /home/insightlab/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/insightlab/.local/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets>=7.5) (1.16.0)
# Requirement already satisfied: webencodings in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.5.1)
# Requirement already satisfied: fqdn in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.5.1)
# Requirement already satisfied: isoduration in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (3.0.0)
# Requirement already satisfied: uri-template in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.6)
# Requirement already satisfied: pycparser in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.9.0.20240821)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyterlab "ipywidgets>=7.5"
# Out:
# Requirement already satisfied: jupyterlab in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (4.2.5)
# Requirement already satisfied: ipywidgets>=7.5 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: async-lru>=1.0.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyterlab) (3.1.4)
# Requirement already satisfied: jupyter-core in /home/insightlab/.local/lib/python3.10/site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in /home/insightlab/.local/lib/python3.10/site-packages (from jupyterlab) (24.1)
# Requirement already satisfied: setuptools>=40.1.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (72.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab) (2.0.1)
# Requirement already satisfied: tornado>=6.2.0 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyterlab) (6.4.1)
# Requirement already satisfied: traitlets in /home/insightlab/.local/lib/python3.10/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /home/insightlab/.local/lib/python3.10/site-packages (from ipywidgets>=7.5) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/insightlab/.local/lib/python3.10/site-packages (from ipywidgets>=7.5) (8.26.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from ipywidgets>=7.5) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from ipywidgets>=7.5) (3.0.13)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/insightlab/.local/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab) (4.12.2)
# Requirement already satisfied: anyio in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab) (4.4.0)
# Requirement already satisfied: certifi in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab) (1.0.5)
# Requirement already satisfied: idna in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab) (2.10)
# Requirement already satisfied: sniffio in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.8.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/insightlab/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (26.0.3)
# Requirement already satisfied: decorator in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (2.18.0)
# Requirement already satisfied: stack-data in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (1.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/insightlab/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/insightlab/.local/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-core->jupyterlab) (4.2.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.32.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/insightlab/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/insightlab/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.1.0)
# Requirement already satisfied: defusedxml in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/insightlab/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/insightlab/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/insightlab/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/insightlab/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (2.4.1)
# Requirement already satisfied: pure-eval in /home/insightlab/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/insightlab/.local/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets>=7.5) (1.16.0)
# Requirement already satisfied: webencodings in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: fqdn in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.6)
# Requirement already satisfied: pycparser in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20240821)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
#import plotly.graph_objects as go

# %%
import cudf
import cugraph
import networkx as nx
import plotly.graph_objs as go
from cuml.manifold import UMAP
# Out:
# /home/insightlab/anaconda3/envs/similarity/lib/python3.10/site-packages/cupy/_environment.py:540: UserWarning:
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy, cupy-cuda12x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------
#
#   warnings.warn(f'''

# %%
import plotly.io as pio

# %% [markdown]
# ## Identificación de Patrones en las Redes de Productos

# %%
df_ofertas_relampago = pd.read_csv('/home/insightlab/Documents/MercadoLibre/arquivos/ofertas_relampago.csv', encoding='latin1')

# %%
# Crear un dataframe con las combinaciones de productos que se venden juntos en la misma oferta
product_pairs = []

for _, group in df_ofertas_relampago.groupby('OFFER_START_DATE'):
    products = group['DOMAIN_ID'].unique()
    if len(products) > 1:
        pairs = list(itertools.combinations(products, 2))
        product_pairs.extend(pairs)

# %%
# Convertir las combinaciones a cuDF DataFrame
df_pairs = cudf.DataFrame(product_pairs, columns=['Product_A', 'Product_B'])

# Contar las veces que cada par de productos aparece juntos
df_pairs_count = df_pairs.groupby(['Product_A', 'Product_B']).size().reset_index(name='count')

# %%
# Crear el grafo usando cuGraph
G_cugraph = cugraph.Graph()
G_cugraph.from_cudf_edgelist(df_pairs_count, source='Product_A', destination='Product_B', edge_attr='count')

# %%
# Calcular la centralidad de intermediación en GPU con cuGraph
betweenness_centrality = cugraph.centrality.betweenness_centrality(G_cugraph)

# Ordenar el DataFrame por la columna 'betweenness' de forma descendente
betweenness_sorted = betweenness_centrality.sort_values('betweenness_centrality', ascending=False)

# Seleccionar los 10 nodos más críticos (con mayor centralidad)
top_10_critical_nodes = betweenness_sorted.head(10)

# Convertir de nuevo a CPU (pandas) para visualización con NetworkX y Plotly
df_pairs_count_cpu = df_pairs_count.to_pandas()

# Crear grafo en NetworkX para usar layout (cuGraph no soporta layouts)
G = nx.Graph()

# Añadir los nodos y aristas (con pesos)
for _, row in df_pairs_count_cpu.iterrows():
    G.add_edge(row['Product_A'], row['Product_B'], weight=row['count'])

# %%
betweenness_centrality
# Out:
#       betweenness_centrality                                   vertex
# 0                   0.000000  MLM-MANICURE_PRACTICE_HANDS_AND_FINGERS
# 1                   0.000000                MLM-SCULPTURED_NAIL_FORMS
# 2                   0.000000              MLM-WATERPROOF_CAMERA_CASES
# 3                   0.000000                        MLM-CAKE_LEVELERS
# 4                   0.000000                       MLM-MOTOR_STARTERS
# ...                      ...                                      ...
# 1261                0.002488                    MLM-BODYWEIGHT_SCALES
# 1262                0.002550                MLM-CELLPHONE_ACCESSORIES
# 1263                0.002428                          MLM-MICROPHONES
# 1264                0.002448                        MLM-HATS_AND_CAPS
# 1265                0.002810                        MLM-GYM_DUMBBELLS
#
# [1266 rows x 2 columns]

# %%
top_10_critical_nodes
# Out:
#      betweenness_centrality                              vertex
# 288                0.003702                    MLM-WRISTWATCHES
# 289                0.003702   MLM-SURGICAL_AND_INDUSTRIAL_MASKS
# 290                0.003702                         MLM-WALLETS
# 291                0.003702                          MLM-SHORTS
# 292                0.003702          MLM-SANDALS_AND_FLIP_FLOPS
# 293                0.003702                           MLM-PANTS
# 294                0.003702                      MLM-HEADPHONES
# 295                0.003684                        MLM-SNEAKERS
# 296                0.003677  MLM-AEROBICS_AND_FITNESS_EQUIPMENT
# 297                0.003654                  MLM-ACTION_FIGURES

# %%
# Crear un dataframe con las combinaciones de productos que se venden juntos en la misma oferta
product_pairs = []

for _, group in df_ofertas_relampago.groupby('OFFER_START_DATE'):
    products = group['DOMAIN_ID'].unique()
    if len(products) > 1:
        pairs = list(itertools.combinations(products, 2))
        product_pairs.extend(pairs)

# Convertir a DataFrame
df_pairs = pd.DataFrame(product_pairs, columns=['Product_A', 'Product_B'])

# Contar las veces que cada par de productos aparece juntos
df_pairs_count = df_pairs.groupby(['Product_A', 'Product_B']).size().reset_index(name='count')

# Construcción de la red
G_nx = nx.Graph()

# Añadir los nodos y aristas (enlaces)
for _, row in df_pairs_count.iterrows():
    G_nx.add_edge(row['Product_A'], row['Product_B'], weight=row['count'])

# %%
pio.renderers.default = 'browser'

# %%
# Generar la matriz de adyacencia del grafo en formato scipy sparse matrix
adj_matrix = nx.to_scipy_sparse_array(G_nx)  # Usar to_scipy_sparse_array para obtener la matriz dispersa

# Usar UMAP para calcular el layout en GPU
umap_model = UMAP(n_components=2)  # Queremos un layout en 2D
layout = umap_model.fit_transform(adj_matrix.toarray())  # Calcular el layout con UMAP

# Mapear las posiciones generadas por UMAP a los nodos
pos_umap = {node: layout[i] for i, node in enumerate(G_nx.nodes())}

# Crear listas temporales para las aristas y nodos
edge_x = []
edge_y = []

# Crear las trazas de aristas
for edge in G_nx.edges():
    x0, y0 = pos_umap[edge[0]]
    x1, y1 = pos_umap[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

# Crear traza de aristas
edge_trace = go.Scatter(
    x=edge_x,
    y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

# Crear las posiciones de los nodos
node_x = []
node_y = []
node_color = []
node_size = []

# Calcular la centralidad de intermediación con cuGraph
betweenness_centrality = cugraph.centrality.betweenness_centrality(G_cugraph)
top_10_critical_nodes = betweenness_centrality.sort_values('betweenness_centrality', ascending=False).head(10)

# Trazar los nodos
for node in G_nx.nodes():
    x, y = pos_umap[node]
    node_x.append(x)
    node_y.append(y)
    
    if node in top_10_critical_nodes['vertex'].values_host:
        node_color.append('red')  # Nodos críticos
        #node_size.append(1000 * betweenness_centrality.query(f'vertex == {node}')['betweenness_centrality'].values[0])
        betweenness_value = betweenness_centrality.loc[betweenness_centrality['vertex'] == node, 'betweenness_centrality'].values[0]
        node_size.append(1000 * betweenness_value.item())  # Convertir el array a escalar con .item()


    else:
        node_color.append('blue')  # Otros nodos
        node_size.append(5)  # Tamaño por defecto

# Crear la traza de nodos
node_trace = go.Scatter(
    x=node_x,
    y=node_y,
    text=[f'<br>{node}' for node in G_nx.nodes()],
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        reversescale=True,
        color=node_color,
        size=node_size,
        colorbar=dict(
            thickness=15,
            title='Nivel de Criticidad',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# Crear la figura en Plotly
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='<br>Network graph accelerated with UMAP and GPU',
                    titlefont_size=16,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40),
                    annotations=[dict(
                        text="Python code: <a href='https://plotly.com/'> Plotly.com</a>",
                        showarrow=False,
                        xref="paper", yref="paper",
                        x=0.005, y=-0.002)],
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

# Mostrar la figura
fig.show()
